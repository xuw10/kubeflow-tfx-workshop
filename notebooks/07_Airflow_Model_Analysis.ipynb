# %% [markdown]
# # Analyze Model Performance
#
# Use the code below to run TensorFlow Model Analysis on the model in your pipeline. Start by importing and opening the metadata store.

# %%
from __future__ import print_function

import os
import tfx_utils

def _make_default_sqlite_uri(pipeline_name):
    return os.path.join(os.environ['HOME'], 'airflow-dags/tfx/metadata', pipeline_name, 'metadata.db')

def get_metadata_store(pipeline_name):
    return tfx_utils.TFXReadonlyMetadataStore.from_sqlite_db(_make_default_sqlite_uri(pipeline_name))

pipeline_name = 'taxi' # or taxi_solution
pipeline_db_path = _make_default_sqlite_uri(pipeline_name)
print('Pipeline DB:\n{}'.format(pipeline_db_path))

store = get_metadata_store(pipeline_name)
# Out:
# Pipeline DB:
# /home/jovyan/airflow-dags/tfx/metadata/taxi/metadata.db

# %% [markdown]
# # Show Model Artifacts

# %%
store.get_artifacts_of_type_df(tfx_utils.TFXArtifactTypes.MODEL)
# Out:
#                                                   URI SPAN        TYPE_NAME  \
# ID
# 11  /mnt/pipelineai/users/airflow-dags/tfx/pipelin...    1  ModelExportPath
#
#    SPLIT      STATE
# ID
# 11        published

# %% [markdown]
# # TensorFlow Model Analysis (TFMA)

# %%
#store.display_tfma_analysis(<insert-model-ID>, slicing_column='trip_start_hour')
store.display_tfma_analysis(<insert-model-ID>, slicing_column='trip_start_hour')
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow_model_analysis/evaluators/metrics_and_plots_evaluator.py:83: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING: Logging before flag parsing goes to stderr.
# W0614 02:52:30.286049 140316963903296 deprecation.py:323] From /opt/conda/lib/python3.6/site-packages/tensorflow_model_analysis/evaluators/metrics_and_plots_evaluator.py:83: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-6-6decb10b128c> in <module>
#       1 #store.display_tfma_analysis(<insert-model-ID>, slicing_column='trip_start_hour')
# ----> 2 store.display_tfma_analysis(11, slicing_column='trip_start_hour')
#
# ~/notebooks/tfx_utils.py in display_tfma_analysis(self, model_id, slicing_column)
#      80     if tfma_artifact:
#      81       return tfma.view.render_slicing_metrics(
# ---> 82           tfma.load_eval_result(tfma_artifact.uri),
#      83           slicing_column=slicing_column)
#      84
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_model_analysis/api/model_eval_lib.py in load_eval_result(output_path)
#     185   """Creates an EvalResult object for use with the visualization functions."""
#     186   metrics_proto_list = metrics_and_plots_evaluator.load_and_deserialize_metrics(
# --> 187       path=os.path.join(output_path, _METRICS_OUTPUT_FILE))
#     188   plots_proto_list = metrics_and_plots_evaluator.load_and_deserialize_plots(
#     189       path=os.path.join(output_path, _PLOTS_OUTPUT_FILE))
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_model_analysis/evaluators/metrics_and_plots_evaluator.py in load_and_deserialize_metrics(path)
#      81     path: Text) -> List[Tuple[slicer.SliceKeyType, Any]]:
#      82   result = []
# ---> 83   for record in tf.python_io.tf_record_iterator(path):
#      84     metrics_for_slice = metrics_for_slice_pb2.MetricsForSlice.FromString(record)
#      85     result.append((
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/lib/io/tf_record.py in tf_record_iterator(path, options)
#     172   with errors.raise_exception_on_not_ok_status() as status:
#     173     reader = pywrap_tensorflow.PyRecordReader_New(
# --> 174         compat.as_bytes(path), 0, compat.as_bytes(compression_type), status)
#     175
#     176   if reader is None:
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# NotFoundError: /mnt/pipelineai/users/airflow-dags/tfx/pipelines/taxi/Evaluator/output/7/metrics; No such file or directory

# %% [markdown]
# # Plot the Artifact Lineage

# %%
# Try different IDs here. Click stop in the plot when changing IDs.
# %matplotlib notebook
store.plot_artifact_lineage(<insert-model-ID>)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# /opt/conda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /opt/conda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
